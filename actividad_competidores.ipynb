# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('juegos_olimpicos.csv')

# %%
#Aldair de Jesus De Leon Hernandez
#Actividad basica 
#Punto 1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 15 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   ID         271116 non-null  int64
#  1   Nombre     271116 non-null  object
#  2   Sexo       271116 non-null  object
#  3   Edad       261642 non-null  float64
#  4   Altura     210945 non-null  float64
#  5   Peso       208241 non-null  float64
#  6   Equipo     271116 non-null  object
#  7   NOC        271116 non-null  object
#  8   Juegos     271116 non-null  object
#  9   Anio       271116 non-null  int64
#  10  Temporada  271116 non-null  object
#  11  Ciudad     271116 non-null  object
#  12  Deporte    271116 non-null  object
#  13  Deporte.1  271116 non-null  object
#  14  Medalla    39783 non-null   object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 31.0+ MB

# %%
df.head()
# Out:
#    ID                    Nombre Sexo  Edad  Altura  Peso          Equipo  NOC  \
# 0   1                 A Dijiang    M  24.0   180.0  80.0           China  CHN
# 1   2                  A Lamusi    M  23.0   170.0  60.0           China  CHN
# 2   3       Gunnar Nielsen Aaby    M  24.0     NaN   NaN         Denmark  DEN
# 3   4      Edgar Lindenau Aabye    M  34.0     NaN   NaN  Denmark/Sweden  DEN
# 4   5  Christine Jacoba Aaftink    F  21.0   185.0  82.0     Netherlands  NED
#
#         Juegos  Anio Temporada     Ciudad        Deporte  \
# 0  1992 Summer  1992    Summer  Barcelona     Basketball
# 1  2012 Summer  2012    Summer     London           Judo
# 2  1920 Summer  1920    Summer  Antwerpen       Football
# 3  1900 Summer  1900    Summer      Paris     Tug-Of-War
# 4  1988 Winter  1988    Winter    Calgary  Speed Skating
#
#                           Deporte.1 Medalla
# 0       Basketball Men's Basketball     NaN
# 1      Judo Men's Extra-Lightweight     NaN
# ...

# %%
df['Medalla'].unique()
# Out:
# array([nan, 'Gold', 'Bronze', 'Silver'], dtype=object)

# %%
bronce=df['Medalla']=='Bronze'
oro=df['Medalla']=='Gold'
plata=df['Medalla']=='Silver'

# %%
mas_veterano=df['Edad'].max()
df[df['Edad']==mas_veterano]
# Out:
#             ID                  Nombre Sexo  Edad  Altura  Peso  \
# 257054  128719  John Quincy Adams Ward    M  97.0     NaN   NaN
#
#                Equipo  NOC       Juegos  Anio Temporada     Ciudad  \
# 257054  United States  USA  1928 Summer  1928    Summer  Amsterdam
#
#                  Deporte                                    Deporte.1 Medalla
# 257054  Art Competitions  Art Competitions Mixed Sculpturing, Statues     NaN

# %%
df[oro|plata|bronce].head()
# Out:
#     ID                    Nombre Sexo  Edad  Altura  Peso          Equipo  \
# 3    4      Edgar Lindenau Aabye    M  34.0     NaN   NaN  Denmark/Sweden
# 37  15      Arvo Ossian Aaltonen    M  30.0     NaN   NaN         Finland
# 38  15      Arvo Ossian Aaltonen    M  30.0     NaN   NaN         Finland
# 40  16  Juhamatti Tapio Aaltonen    M  28.0   184.0  85.0         Finland
# 41  17   Paavo Johannes Aaltonen    M  28.0   175.0  64.0         Finland
#
#     NOC       Juegos  Anio Temporada     Ciudad     Deporte  \
# 3   DEN  1900 Summer  1900    Summer      Paris  Tug-Of-War
# 37  FIN  1920 Summer  1920    Summer  Antwerpen    Swimming
# 38  FIN  1920 Summer  1920    Summer  Antwerpen    Swimming
# 40  FIN  2014 Winter  2014    Winter      Sochi  Ice Hockey
# 41  FIN  1948 Summer  1948    Summer     London  Gymnastics
#
#                                  Deporte.1 Medalla
# 3              Tug-Of-War Men's Tug-Of-War    Gold
# 37  Swimming Men's 200 metres Breaststroke  Bronze
# ...

# %%
df_ganadores=df[oro|plata|bronce]
df_ganadores.head()
# Out:
#     ID                    Nombre Sexo  Edad  Altura  Peso          Equipo  \
# 3    4      Edgar Lindenau Aabye    M  34.0     NaN   NaN  Denmark/Sweden
# 37  15      Arvo Ossian Aaltonen    M  30.0     NaN   NaN         Finland
# 38  15      Arvo Ossian Aaltonen    M  30.0     NaN   NaN         Finland
# 40  16  Juhamatti Tapio Aaltonen    M  28.0   184.0  85.0         Finland
# 41  17   Paavo Johannes Aaltonen    M  28.0   175.0  64.0         Finland
#
#     NOC       Juegos  Anio Temporada     Ciudad     Deporte  \
# 3   DEN  1900 Summer  1900    Summer      Paris  Tug-Of-War
# 37  FIN  1920 Summer  1920    Summer  Antwerpen    Swimming
# 38  FIN  1920 Summer  1920    Summer  Antwerpen    Swimming
# 40  FIN  2014 Winter  2014    Winter      Sochi  Ice Hockey
# 41  FIN  1948 Summer  1948    Summer     London  Gymnastics
#
#                                  Deporte.1 Medalla
# 3              Tug-Of-War Men's Tug-Of-War    Gold
# 37  Swimming Men's 200 metres Breaststroke  Bronze
# ...

# %%
df_ganadores['Edad'].max()
# Out:
# 73.0

# %%
df_ganadores['Edad']==df_ganadores['Edad'].max()
# Out:
# 3         False
# 37        False
# 38        False
# 40        False
# 41        False
#           ...
# 271078    False
# 271080    False
# 271082    False
# 271102    False
# 271103    False
# Name: Edad, Length: 39783, dtype: bool

# %%
filtro_veterano=df_ganadores['Edad']==df_ganadores['Edad'].max()

# %%
df_ganadores[filtro_veterano]
# Out:
#           ID                                         Nombre Sexo  Edad  \
# 44584  22984  John (Herbert Crawford-) Copley (Williamson-)    M  73.0
#
#        Altura  Peso         Equipo  NOC       Juegos  Anio Temporada  Ciudad  \
# 44584     NaN   NaN  Great Britain  GBR  1948 Summer  1948    Summer  London
#
#                 Deporte                                      Deporte.1 Medalla
# 44584  Art Competitions  Art Competitions Mixed Painting, Graphic Arts  Silver

# %%
filtro_medalla=df['Medalla'].notnull()

# %%
df[filtro_medalla].head(2)
# Out:
#     ID                Nombre Sexo  Edad  Altura  Peso          Equipo  NOC  \
# 3    4  Edgar Lindenau Aabye    M  34.0     NaN   NaN  Denmark/Sweden  DEN
# 37  15  Arvo Ossian Aaltonen    M  30.0     NaN   NaN         Finland  FIN
#
#          Juegos  Anio Temporada     Ciudad     Deporte  \
# 3   1900 Summer  1900    Summer      Paris  Tug-Of-War
# 37  1920 Summer  1920    Summer  Antwerpen    Swimming
#
#                                  Deporte.1 Medalla
# 3              Tug-Of-War Men's Tug-Of-War    Gold
# 37  Swimming Men's 200 metres Breaststroke  Bronze

# %%
edad_maxima=df[filtro_medalla]['Edad'].max()
edad_maxima
# Out:
# 73.0

# %%
df[(filtro_medalla)&(df['Edad']==edad_maxima)]
# Out:
#           ID                                         Nombre Sexo  Edad  \
# 44584  22984  John (Herbert Crawford-) Copley (Williamson-)    M  73.0
#
#        Altura  Peso         Equipo  NOC       Juegos  Anio Temporada  Ciudad  \
# 44584     NaN   NaN  Great Britain  GBR  1948 Summer  1948    Summer  London
#
#                 Deporte                                      Deporte.1 Medalla
# 44584  Art Competitions  Art Competitions Mixed Painting, Graphic Arts  Silver

# %%
# Punto 2

# %%
medalla_oro=df['Medalla']=='Gold'
medalla_oro
# Out:
# 0         False
# 1         False
# 2         False
# 3          True
# 4         False
#           ...
# 271111    False
# 271112    False
# 271113    False
# 271114    False
# 271115    False
# Name: Medalla, Length: 271116, dtype: bool

# %%
ganador_joven=df[medalla_oro]['Edad'].min()
ganador_joven
# Out:
# 13.0

# %%
df[(medalla_oro)&(df['Edad']==ganador_joven)]
# Out:
#             ID                              Nombre Sexo  Edad  Altura  Peso  \
# 27207    14142                       Hans Bourquin    M  13.0     NaN   NaN
# 52010    26731  Donna Elizabeth de Varona (-Pinto)    F  13.0   168.0  61.0
# 73581    37398                          Fu Mingxia    F  13.0   160.0  48.0
# 78544    39866        Marjorie Gestring (-Redlick)    F  13.0     NaN   NaN
# 119277   60384                          Kim Yun-Mi    F  13.0   160.0  48.0
# 200704  100797       Aileen Muriel Riggin (-Soule)    F  13.0   142.0   NaN
# 268602  134381                         Klaus Zerta    M  13.0   165.0  48.0
#
#                Equipo  NOC       Juegos  Anio Temporada       Ciudad  \
# 27207     Switzerland  SUI  1928 Summer  1928    Summer    Amsterdam
# 52010   United States  USA  1960 Summer  1960    Summer         Roma
# 73581           China  CHN  1992 Summer  1992    Summer    Barcelona
# 78544   United States  USA  1936 Summer  1936    Summer       Berlin
# ...

# %%
# Punto 3

# %%
df_ganadores.head()
# Out:
#     ID                    Nombre Sexo  Edad  Altura  Peso          Equipo  \
# 3    4      Edgar Lindenau Aabye    M  34.0     NaN   NaN  Denmark/Sweden
# 37  15      Arvo Ossian Aaltonen    M  30.0     NaN   NaN         Finland
# 38  15      Arvo Ossian Aaltonen    M  30.0     NaN   NaN         Finland
# 40  16  Juhamatti Tapio Aaltonen    M  28.0   184.0  85.0         Finland
# 41  17   Paavo Johannes Aaltonen    M  28.0   175.0  64.0         Finland
#
#     NOC       Juegos  Anio Temporada     Ciudad     Deporte  \
# 3   DEN  1900 Summer  1900    Summer      Paris  Tug-Of-War
# 37  FIN  1920 Summer  1920    Summer  Antwerpen    Swimming
# 38  FIN  1920 Summer  1920    Summer  Antwerpen    Swimming
# 40  FIN  2014 Winter  2014    Winter      Sochi  Ice Hockey
# 41  FIN  1948 Summer  1948    Summer     London  Gymnastics
#
#                                  Deporte.1 Medalla
# 3              Tug-Of-War Men's Tug-Of-War    Gold
# 37  Swimming Men's 200 metres Breaststroke  Bronze
# ...

# %%
df_ganadores["ID"].value_counts()
# Out:
# 94406     28
# 67046     18
# 4198      15
# 11951     13
# 109161    13
#           ..
# 66299      1
# 66298      1
# 20756      1
# 20757      1
# 4          1
# Name: ID, Length: 28251, dtype: int64

# %%
max_ganador=df_ganadores[df_ganadores["ID"]==94406]

# %%
max_ganador.head()
# Out:
#            ID                   Nombre Sexo  Edad  Altura  Peso  \
# 187888  94406  Michael Fred Phelps, II    M  19.0   193.0  91.0
# 187889  94406  Michael Fred Phelps, II    M  19.0   193.0  91.0
# 187890  94406  Michael Fred Phelps, II    M  19.0   193.0  91.0
# 187891  94406  Michael Fred Phelps, II    M  19.0   193.0  91.0
# 187892  94406  Michael Fred Phelps, II    M  19.0   193.0  91.0
#
#                Equipo  NOC       Juegos  Anio Temporada  Ciudad   Deporte  \
# 187888  United States  USA  2004 Summer  2004    Summer  Athina  Swimming
# 187889  United States  USA  2004 Summer  2004    Summer  Athina  Swimming
# 187890  United States  USA  2004 Summer  2004    Summer  Athina  Swimming
# 187891  United States  USA  2004 Summer  2004    Summer  Athina  Swimming
# 187892  United States  USA  2004 Summer  2004    Summer  Athina  Swimming
#
#                                             Deporte.1 Medalla
# 187888            Swimming Men's 200 metres Freestyle  Bronze
# ...

# %%
max_ganador.to_csv('Maximo_ganador_jo.csv',index=False)
