# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv('juegos_olimpicos.csv')

# %%
import matplotlib.pyplot as plt

# %%
df.head()
# Out:
#    ID                    Nombre Sexo  Edad  Altura  Peso          Equipo  NOC  \
# 0   1                 A Dijiang    M  24.0   180.0  80.0           China  CHN
# 1   2                  A Lamusi    M  23.0   170.0  60.0           China  CHN
# 2   3       Gunnar Nielsen Aaby    M  24.0     NaN   NaN         Denmark  DEN
# 3   4      Edgar Lindenau Aabye    M  34.0     NaN   NaN  Denmark/Sweden  DEN
# 4   5  Christine Jacoba Aaftink    F  21.0   185.0  82.0     Netherlands  NED
#
#         Juegos  Anio Temporada     Ciudad        Deporte  \
# 0  1992 Summer  1992    Summer  Barcelona     Basketball
# 1  2012 Summer  2012    Summer     London           Judo
# 2  1920 Summer  1920    Summer  Antwerpen       Football
# 3  1900 Summer  1900    Summer      Paris     Tug-Of-War
# 4  1988 Winter  1988    Winter    Calgary  Speed Skating
#
#                           Deporte.1 Medalla
# 0       Basketball Men's Basketball     NaN
# 1      Judo Men's Extra-Lightweight     NaN
# ...

# %%
games=df.groupby(df['Juegos'])
games.first()
# Out:
#                ID                              Nombre Sexo  Edad  Altura  \
# Juegos
# 1896 Summer  1724              Aristidis Akratopoulos    M  24.0   183.0
# 1900 Summer     4                Edgar Lindenau Aabye    M  34.0   168.0
# 1904 Summer   404         Louis Grenville "Lou" Abell    M  19.0   168.0
# 1906 Summer   139              George "Ioannis" Abbot    M  21.0   182.0
# 1908 Summer   635                     Alfredo Accorsi    M  27.0   188.0
# 1912 Summer    15                Arvo Ossian Aaltonen    M  22.0   181.0
# 1920 Summer     3                 Gunnar Nielsen Aaby    M  24.0   177.0
# 1924 Summer    15                Arvo Ossian Aaltonen    M  34.0   177.0
# 1924 Winter   391                  Clarence John Abel    M  23.0   185.0
# 1928 Summer    47                Erling Rudolf Aastad    M  30.0   177.0
# 1928 Winter   529     Karl Gustaf Emanuel Abrahamsson    M  31.0   177.0
# 1932 Summer     8  Cornelia "Cor" Aalten (-Strannood)    F  18.0   168.0
# ...

# %%
games.size().index
# Out:
# Index(['1896 Summer', '1900 Summer', '1904 Summer', '1906 Summer',
#        '1908 Summer', '1912 Summer', '1920 Summer', '1924 Summer',
#        '1924 Winter', '1928 Summer', '1928 Winter', '1932 Summer',
#        '1932 Winter', '1936 Summer', '1936 Winter', '1948 Summer',
#        '1948 Winter', '1952 Summer', '1952 Winter', '1956 Summer',
#        '1956 Winter', '1960 Summer', '1960 Winter', '1964 Summer',
#        '1964 Winter', '1968 Summer', '1968 Winter', '1972 Summer',
#        '1972 Winter', '1976 Summer', '1976 Winter', '1980 Summer',
#        '1980 Winter', '1984 Summer', '1984 Winter', '1988 Summer',
#        '1988 Winter', '1992 Summer', '1992 Winter', '1994 Winter',
#        '1996 Summer', '1998 Winter', '2000 Summer', '2002 Winter',
#        '2004 Summer', '2006 Winter', '2008 Summer', '2010 Winter',
#        '2012 Summer', '2014 Winter', '2016 Summer'],
#       dtype='object', name='Juegos')

# %%
def cm2pulg(valor):
    return valor/2.54

# %%
#Aldair de Jesus De León Hernandez
#Actividad Grafica Pastel

# %%
plt.rcParams.keys()
# Out:
# KeysView(RcParams({'_internal.classic_mode': False,
#           'agg.path.chunksize': 0,
#           'animation.bitrate': -1,
#           'animation.codec': 'h264',
#           'animation.convert_args': [],
#           'animation.convert_path': 'convert',
#           'animation.embed_limit': 20.0,
#           'animation.ffmpeg_args': [],
#           'animation.ffmpeg_path': 'ffmpeg',
#           'animation.frame_format': 'png',
#           'animation.html': 'none',
#           'animation.writer': 'ffmpeg',
#           'axes.autolimit_mode': 'data',
#           'axes.axisbelow': True,
#           'axes.edgecolor': 'white',
#           'axes.facecolor': '#EAEAF2',
#           'axes.formatter.limits': [-5, 6],
#           'axes.formatter.min_exponent': 0,
#           'axes.formatter.offset_threshold': 4,
#           'axes.formatter.use_locale': False,
#           'axes.formatter.use_mathtext': False,
#           'axes.formatter.useoffset': True,
#           'axes.grid': True,
# ...

# %%
fig, ax=plt.subplots(figsize=(10,8))
plt.pie(games.size().values, labels=games.size().index)
ax.set_title('Participantes por año en J.J.O.O\n',fontsize=18, fontweight='bold')
plt.rcParams.update({'font.size':8,'legend.loc':'upper right'})
ax.legend(games.size().values)
plt.show()
plt.savefig('grafica_pastel_juegos.jpg',dpi=300,bbox_inches='tight')
